# %%
# -*- coding:utf-8 -*-
import requests
from bs4 import BeautifulSoup
import json
import re
import os

# 通过音乐的id得到歌词
def get_lyric_by_music_id(music_id):
    lrc_url = 'http://music.163.com/api/song/lyric?' + 'id=' + str(music_id) + '&lv=1&kv=1&tv=-1'

    lyric = requests.get(lrc_url)
    json_obj = lyric.text
    j = json.loads(json_obj)
    
    # 部分歌曲没有歌词，这里引入一个异常
    try:
        lrc=j['lrc']['lyric']
        pat=re.compile(r'\[.*\]')
        lrc=re.sub(pat,"",lrc)
        lrc=lrc.strip()
        return lrc
    except KeyError as e:
        pass
    
# 通过一个歌手的id下载其最火的五十首歌的全部歌词
def spider_by_singer(singer_id):
    singer_url = 'http://music.163.com/artist?id=' + str(singer_id)
    web_data = requests.get(singer_url)
    soup = BeautifulSoup(web_data.text,'lxml')
    singer_name = soup.select("#artist-name")

    singer_name = singer_name[0].get('title')

    r = soup.find('ul',{'class':'f-hide'}).find_all('a')
    r = (list(r))
    music_id_set = []
    music_name_set = []
    for each in r:
        song_name = each.text
        music_name_set.append(song_name)

        song_id = each.attrs["href"]
        music_id_set.append(song_id[9:])
        print 'music id:', song_id[9:], '\t name:', song_name
        
    # 将音乐名字和音乐id组成一个字典
    dic = dict(map(lambda x,y:[x,y],music_name_set,music_id_set))

    out_file_path = "./lyrics/%s.txt" % singer_name
    if os.path.isfile(out_file_path):
        os.remove(out_file_path)
        
    success_count = 0
    for music_id in music_id_set:
        top_50_lyric = get_lyric_by_music_id(music_id)
        
        #单个文件存储一个歌手的50首热门歌曲的歌词并以歌手的名字命名
        f = open(out_file_path,"ab")
        try:
            f.write(top_50_lyric.encode('utf-8'))
            f.close()
            success_count += 1
        except AttributeError as e2:
            print 'error when deal music:', music_id
            pass

    print '\nSinger:', singer_name, '\tSucceed Count:', success_count
    
# 周杰伦 6452
# 陈奕迅 2116
# 赵雷 6731
spider_by_singer('6731')
# Out:
# music id: 418603077 	 name: 告白气球
# music id: 186016 	 name: 晴天
# music id: 29818120 	 name: 算什么男人
# music id: 185709 	 name: 稻香
# music id: 186001 	 name: 七里香
# music id: 186119 	 name: 简单爱
# music id: 185809 	 name: 彩虹
# music id: 186005 	 name: 搁浅
# music id: 185821 	 name: 最长的电影
# music id: 185820 	 name: 甜甜的
# music id: 185868 	 name: 不能说的秘密
# music id: 185924 	 name: 一路向北
# music id: 185904 	 name: 夜曲
# music id: 185699 	 name: 说好的幸福呢
# music id: 185912 	 name: 枫
# music id: 186055 	 name: 回到过去
# music id: 186139 	 name: 安静
# music id: 185668 	 name: 烟花易冷
# music id: 185884 	 name: 退后
# music id: 185811 	 name: 青花瓷
# music id: 185694 	 name: 给我一首歌的时间
# music id: 25641369 	 name: 明明就
# music id: 185815 	 name: 蒲公英的约定
# music id: 186160 	 name: 龙卷风
# music id: 186014 	 name: 以父之名
# music id: 186046 	 name: 半岛铁盒
# music id: 186125 	 name: 开不了口
# music id: 185920 	 name: 珊瑚海
# music id: 418602087 	 name: 爱情废柴
# music id: 186002 	 name: 借口
# music id: 185908 	 name: 黑色毛衣
# music id: 186149 	 name: 星晴
# music id: 417250561 	 name: 不该(with aMEI)
# music id: 185667 	 name: 说了再见
# music id: 185818 	 name: 我不配
# music id: 185906 	 name: 发如雪
# music id: 186010 	 name: 轨迹
# music id: 185879 	 name: 听妈妈的话
# music id: 29822018 	 name: 手写的从前
# music id: 186145 	 name: 可爱女人
# music id: 185878 	 name: 夜的第七章
# music id: 186018 	 name: 东风破
# music id: 25641368 	 name: 红尘客栈
# music id: 186109 	 name: 世界末日
# music id: 186114 	 name: 爱在西元前
# music id: 186103 	 name: 蜗牛
# music id: 29822014 	 name: 听见下雨的声音
# music id: 418603076 	 name: 一点点
# music id: 298317 	 name: 屋顶
# music id: 210049 	 name: 布拉格广场
#
# Singer: 周杰伦 - Jay Chou 	Succeed Count: 50
